# %%
#use fincial modeling prpep api to get recession percentages
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

# %%
import pandas as pd
import certifi
import json
from pathlib import Path
# %matplotlib inline

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v4/economic?name=smoothedUSRecessionProbabilities&from=2019-07-10&to=2022-09-10&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "date": "2022-07-01",
#         "value": 0.2
#     },
#     {
#         "date": "2022-06-01",
#         "value": 0.24
#     },
#     {
#         "date": "2022-05-01",
#         "value": 0.32
#     },
#     {
#         "date": "2022-04-01",
#         "value": 0.18
#     },
#     {
#         "date": "2022-03-01",
#         "value": 0.2
#     },
#     {
#         "date": "2022-02-01",
#         "value": 0.1
#     },
#     {
#         "date": "2022-01-01",
#         "value": 0.14
#     },
#     {
#         "date": "2021-12-01",
#         "value": 0.42
#     },
#     {
#         "date": "2021-11-01",
#         "value": 0.16
#     },
#     {
#         "date": "2021-10-01",
#         "value": 0.14
#     },
#     {
#         "date": "2021-09-01",
#         "value": 0.5
#     },
#     {
#         "date": "2021-08-01",
#         "value": 0.38
#     },
#     {
#         "date": "2021-07-01",
#         "value": 0.22
#     },
#     {
#         "date": "2021-06-01",
#         "value": 0.16
#     },
#     {
#         "date": "2021-05-01",
#         "value": 0.24
#     },
#     {
#         "date": "2021-04-01",
#         "value": 0.64
#     },
#     {
#         "date": "2021-03-01",
#         "value": 0.16
#     },
#     {
#         "date": "2021-02-01",
#         "value": 0.1
#     },
#     {
#         "date": "2021-01-01",
#         "value": 0.12
#     },
#     {
#         "date": "2020-12-01",
#         "value": 0.24
#     },
#     {
#         "date": "2020-11-01",
#         "value": 0.58
#     },
#     {
#         "date": "2020-10-01",
#         "value": 0.28
#     },
#     {
#         "date": "2020-09-01",
#         "value": 0.18
#     },
#     {
#         "date": "2020-08-01",
#         "value": 0.12
#     },
#     {
#         "date": "2020-07-01",
#         "value": 0.14
#     },
#     {
#         "date": "2020-06-01",
#         "value": 0.16
#     },
#     {
#         "date": "2020-05-01",
#         "value": 0.22
#     },
#     {
#         "date": "2020-04-01",
#         "value": 100.0
#     },
#     {
#         "date": "2020-03-01",
#         "value": 100.0
#     },
#     {
#         "date": "2020-02-01",
#         "value": 0.26
#     },
#     {
#         "date": "2020-01-01",
#         "value": 0.3
#     },
#     {
#         "date": "2019-12-01",
#         "value": 0.62
#     },
#     {
#         "date": "2019-11-01",
#         "value": 0.54
#     },
#     {
#         "date": "2019-10-01",
#         "value": 1.7
#     },
#     {
#         "date": "2019-09-01",
#         "value": 1.24
#     },
#     {
#         "date": "2019-08-01",
#         "value": 0.54
#     }
# ]
# /var/folders/hj/kq6jbljs7lb95ftqpmny2y340000gn/T/ipykernel_34418/654040892.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
