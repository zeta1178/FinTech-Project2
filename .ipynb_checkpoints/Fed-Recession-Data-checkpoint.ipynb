# %%
# !pip install awswrangler
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# ...

# %%
#use fincial modeling prpep api to get recession percentages
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen

# %%
import pandas as pd
import certifi
import json
from pathlib import Path
# %matplotlib inline

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v4/economic?name=smoothedUSRecessionProbabilities&from=2012-07-10&to=2022-09-10&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "date": "2022-07-01",
#         "value": 0.2
#     },
#     {
#         "date": "2022-06-01",
#         "value": 0.24
#     },
#     {
#         "date": "2022-05-01",
#         "value": 0.32
#     },
#     {
#         "date": "2022-04-01",
#         "value": 0.18
#     },
#     {
#         "date": "2022-03-01",
#         "value": 0.2
#     },
#     {
#         "date": "2022-02-01",
#         "value": 0.1
#     },
#     {
#         "date": "2022-01-01",
#         "value": 0.14
#     },
#     {
#         "date": "2021-12-01",
#         "value": 0.42
#     },
#     {
#         "date": "2021-11-01",
#         "value": 0.16
#     },
#     {
#         "date": "2021-10-01",
#         "value": 0.14
#     },
#     {
#         "date": "2021-09-01",
#         "value": 0.5
#     },
#     {
#         "date": "2021-08-01",
#         "value": 0.38
#     },
#     {
#         "date": "2021-07-01",
#         "value": 0.22
#     },
#     {
#         "date": "2021-06-01",
# ...

# %%
var = pd.DataFrame(data)
var
# Out:
#            date  value
# 0    2022-07-01   0.20
# 1    2022-06-01   0.24
# 2    2022-05-01   0.32
# 3    2022-04-01   0.18
# 4    2022-03-01   0.20
# ..          ...    ...
# 115  2012-12-01   0.22
# 116  2012-11-01   0.12
# 117  2012-10-01   0.18
# 118  2012-09-01   0.20
# 119  2012-08-01   0.46
#
# [120 rows x 2 columns]

# %%
import awswrangler as wr

path = f"s3://source-voltar/source/fed.csv"

wr.s3.to_csv(var, path, index=False)
# Out:
# {'paths': ['s3://source-voltar/source/fed.csv'], 'partitions_values': {}}
